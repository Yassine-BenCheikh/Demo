# %% [markdown]
# <a href="https://colab.research.google.com/github/Yassine-BenCheikh/Demo/blob/main/NL2SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_openai langchain_community langchain pymysql chromadb -q

# %%
# !pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 31.8 MB/s eta 0:00:00
# ...

# %%
import mysql.connector

# %%
# Define the connection parameters
config = {
    'user': 'root',
    'password': '123abc765KMBX',
    'host': '127.0.0.1',
    'database': 'sakila'
}

# Attempt to connect to MySQL
try:
    conn = mysql.connector.connect(**config)
    print("Connected to MySQL database!")
    # Optionally, you can execute queries here
    # cursor = conn.cursor()
    # cursor.execute("SELECT * FROM your_table")
    # rows = cursor.fetchall()
    # print(rows)
    # cursor.close()
    conn.close()
except mysql.connector.Error as err:
    print(f"Error: {err}")
# Out:
# Error: 2003 (HY000): Can't connect to MySQL server on '127.0.0.1:3306' (111)

# %%
import mysql.connector

# Connect to MySQL Server
connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='123abc765KMBX',
    database='classicmodels'
)

# Execute a sample query
cursor = connection.cursor()
cursor.execute("SELECT * FROM customers LIMIT 10")

# Fetch and print results
for row in cursor.fetchall():
    print(row)

# Close connection
connection.close()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     322         try:
# --> 323             self._cmysql.connect(**cnx_kwargs)
#     324             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (99)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-14-41eff38217f0> in <cell line: 4>()
#       2
#       3 # Connect to MySQL Server
# ----> 4 connection = mysql.connector.connect(
#       5     host='localhost',
#       6     user='root',
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     320
# ...

# %%
# !systemctl status mysql
# Out:
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down

# %%
# !service mysql status
# Out:
# mysql: unrecognized service

# %%
  # !systemctl start mysql
# Out:
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
host = 'localhost'  # This could be an IP address or domain name
user = 'root'
password = '123abc765KMBX'
database = 'classicmodels'

# Establish connection
conn = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database
)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     322         try:
# --> 323             self._cmysql.connect(**cnx_kwargs)
#     324             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (99)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-37-7601e30636a1> in <cell line: 8>()
#       6
#       7 # Establish connection
# ----> 8 conn = mysql.connector.connect(
#       9     host=host,
#      10     user=user,
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     320
# ...

# %%
print(mysql.connector.__version__)
# Out:
# 8.3.0

# %%
# !service mysql status
# Out:
# mysql: unrecognized service

# %%
# !service mysql start
# Out:
# mysql: unrecognized service
